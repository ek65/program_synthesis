# %%
# %load_ext autoreload

# %%
import os
from unity_utils import UnityTranslator

dir = os.getcwd()
DATA_DIR = dir + '/data/give-and-go'
demos = UnityTranslator.get_from(DATA_DIR, sample_rate=1)
# Out:
# Importing: 100%|██████████| 3/3 [00:03<00:00,  1.28s/it]

# %%
from scenic_fc.api import api
from infer_utils import Inference
acts = Inference.act_from(demos, api, model='gpt-4o')
# Out:
# 100%|██████████| 3/3 [00:19<00:00,  6.45s/it]
# Inference done.

# %%
# %load_ext autoreload
# %autoreload 2

combined = Inference.combine(acts=acts, api=api, model='gpt-4o')
combined.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Editing done.

# %%
[a.id for a in acts]
# Out:
# ['demo_0', 'demo_1', 'demo_2']

# %%
combined.to_dict(expanded=False)
# Out:
# {'outline': 'This final FSM combines the sub-behaviours observed in the demonstrations. The coach begins by ensuring ball possession. When an opponent approaches, the coach passes the ball to a teammate. After the pass, two branches are possible depending on the observed teammate action. In one branch (derived from demo_1 and demo_2), after the teammate secures the ball the coach repositions behind the teammate and then waits to receive a return pass – in one case the return pass is initiated toward a designated location (3.33099127, 9.400471). In the alternative branch (from demo_0), immediately after the pass the coach moves directly to a designated receiving coordinate (0.5502465, 9.197517) to regain possession. Both branches complete the move and go behavior by ending in regained ball possession.',
#  'nodes': [{'target': {'info': 'Coach moves to secure ball possession.',
#     'logic': None,
#     'map': [],
#     'constraints': [],
#     'reasoning': ''},
#    'id': '0',
#    'action': 'MoveTo',
#    'info': 'Coach moves to secure ball possession.',
#    't': {'demo_1': 1, 'demo_2': 1},
#    'termination': 'Coach has secured possession of the ball.'},
#   {'target': {'obj': None,
#     'through': False,
#     'info': 'Coach passes the ball to a teammate when an opponent is observed approaching.'},
#    'id': '1',
#    'action': 'Pass',
#    'info': 'Coach passes the ball to a teammate when an opponent is observed approaching.',
#    't': {'demo_0': 8, 'demo_1': 5, 'demo_2': 5},
#    'termination': 'Ball is released and teammate gains possession.'},
#   {'target': {'info': 'Coach repositions to get behind the teammate in preparation for the return pass.',
#     'logic': None,
#     'map': [],
#     'constraints': [],
#     'reasoning': ''},
#    'id': '2',
#    'action': 'MoveTo',
#    'info': 'Coach repositions to get behind the teammate in preparation for the return pass.',
#    't': {'demo_1': 10, 'demo_2': 7},
#    'termination': 'Coach is positioned behind the teammate.'},
#   {'id': '3',
#    'action': 'Wait',
#    'info': 'Coach waits to receive the ball from the teammate after repositioning.',
#    't': {'demo_1': 19, 'demo_2': 11},
#    'termination': 'Ball possession is regained by Coach.'},
#   {'target': {'info': 'Coach moves to the designated receiving coordinate (0.5502465, 9.197517) to regain possession.',
#     'logic': None,
#     'map': [],
#     'constraints': [],
#     'reasoning': ''},
#    'id': '4',
#    'action': 'MoveTo',
#    'info': 'Coach moves to the designated receiving coordinate (0.5502465, 9.197517) to regain possession.',
#    't': {'demo_0': 22},
#    'termination': 'Ball possession is regained by reaching the receiving position.'}],
#  'edges': [{'id': 0,
#    'prev': '0',
#    'next': '1',
#    'priority': 'precondition',
#    't': {'demo_0': 2, 'demo_1': 2, 'demo_2': 2},
#    'condition': 'Opponent moves towards Coach (observed visually).'},
#   {'id': 1,
#    'prev': '1',
#    'next': '2',
#    'priority': 'precondition',
#    't': {'demo_1': 6, 'demo_2': 6},
#    'condition': "Teammate secures possession after Coach's pass."},
#   {'id': 2,
#    'prev': '2',
#    'next': '3',
#    'priority': 'precondition',
#    't': {'demo_1': 11, 'demo_2': 8},
#    'condition': 'Teammate passes the ball back to Coach or initiates a pass toward the designated location (3.33099127, 9.400471).'},
#   {'id': 3,
#    'prev': '1',
#    'next': '4',
#    'priority': 'precondition',
#    't': {'demo_0': 10},
#    'condition': 'Teammate executes a pass toward the receiving coordinate (0.5502465, 9.197517).'}]}

# %%
combined.to_dict(expanded=False)

# %%
import json

data = combined.to_dict(id='combined_fix', expanded=False)

with open('exports/combined_fix.json', 'w') as f:
    json.dump(data, f, indent=4)

# %%
combined.nodes[0].termination

# %%
import json

OUT_DIR = 'exports'

os.makedirs(OUT_DIR, exist_ok=True)
for idx, a in enumerate(acts):

    id = f'act_{idx + 1}'
    data = a.to_dict(id=id, expanded=False)

    with open(f'{OUT_DIR}/{id}.json', 'w') as f:
        json.dump(data, f, indent=4)

# %%
# %load_ext autoreload
# %autoreload 2

combined.nodes[1].synth(demos, api)

# %%
# %load_ext autoreload
# %autoreload 2

from synth_utils import Synth

synth = Synth(combined, demos, api)
synth.run()

# %%
import json    

program = synth.to_dict()
print(json.dumps(program, indent=4))

# %%
# %load_ext autoreload
# %autoreload 2

demos[0].scene['Coach'][0][20.0].location.x

# %%
for i in demos[0].scene['Coach'][0].location:
    print(i.x)

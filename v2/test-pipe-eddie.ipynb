# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import json
from scenic_fc.api import api

OUT_DIR = 'exports'

with open(OUT_DIR+'/combined-give-and-go1-3.json', 'r') as json_file:
    data = json.load(json_file)
print(data)

from synth_utils import Act
combined = Act.from_dict(data, api)
combined.show()
# Out:
# {'outline': 'Coach executes a give-and-go maneuver that branches based on situational cues. In all scenarios, Coach first secures ball possession. Then, based on the game context, one of three paths is followed: (A) if the opponent applies pressure, Coach passes the ball to the teammate on the right and later regains possession after the teammate returns the pass; (B) if conditions favor a left-side play, Coach passes to the teammate on the left and then repositions in front of the goal post (near coordinate (1.15197432, 9.92925)) to be ready for the return; or (C) in a generic play, after obtaining possession Coach passes to the teammate and then repositions near the original possession spot once the teammate initiates a return pass aimed at (3.24477053, 10.0046186)).', 'nodes': [{'id': '0', 'action': 'GetBallPossession', 'info': 'Coach secures initial ball possession', 't': {'demo_0': 2.5, 'demo_1': 0.5, 'demo_2': 1.0}, 'termination': {'info': 'Ball possession is established and Co
# ...

# %%
import os
from unity_utils import UnityTranslator
import json

dir = os.getcwd()
DATA_DIR = dir + '/data/give-and-go1-3'
demos = UnityTranslator.get_from(DATA_DIR)
# Out:
# Importing: 100%|██████████████████████████████████████| 3/3 [00:10<00:00,  3.48s/it]

# %%
# %load_ext autoreload
# %autoreload 2

from synth_utils import Synth

# combined = acts[0]
synth = Synth(combined, demos, api)
synth.run()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Synthesizing:   0%|                                           | 0/3 [00:00<?, ?it/s]
# GetBallPossession SYNTH
# Synthesizing:  33%|███████████▋                       | 1/3 [00:03<00:07,  3.60s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 8
#       6 # combined = acts[0]
#       7 synth = Synth(combined, demos, api)
# ----> 8 synth.run()
#
# File ~/Desktop/narrated_demo/v2/synth_utils.py:1099, in Synth.run(self)
#    1097 all_elements = self.act.nodes + self.act.edges
#    1098 for elem in tqdm(all_elements, desc="Synthesizing"):
# -> 1099     elem.synth(self.demos, self.api)
#
# File ~/Desktop/narrated_demo/v2/synth_utils.py:395, in Action.synth(self, demos, api)
#     393 def synth(self, demos: list[Demo], api: dict):
#     394     try:
# ...

# %%
import json    

program = synth.to_dict()
print(json.dumps(program, indent=4))
# print(program)

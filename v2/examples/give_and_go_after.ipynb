# %%
import sys, os

dir = os.path.abspath('..')
sys.path.append(os.path.join(dir))
while not os.path.basename(dir) == 'v2':
    parent = os.path.dirname(dir)
    if parent == dir:
        raise FileNotFoundError("No parent directory named 'v2' found.")
    dir = parent

# %%
DATA_NAME = 'jorge-give-and-go'

# %%
from unity_utils import UnityTranslator

DATA_DIR = dir + f'/data/{DATA_NAME}'
demos = UnityTranslator.get_from(DATA_DIR, sample_rate=2)

print(f'Number of frames: {[len(d.video.frame_dir) for d in demos]}')
# Out:
# Importing:   0%|          | 0/3 [00:00<?, ?it/s]
# FPS: 5.0
# Samplerate: 2
# Total # of frames: 327
# Duration of Video: 65.4 seconds
# Importing:  33%|███▎      | 1/3 [00:02<00:04,  2.13s/it]
# Total # of frames saved: 33
# FPS: 5.0
# Samplerate: 2
# Total # of frames: 243
# Duration of Video: 48.6 seconds
# Importing:  67%|██████▋   | 2/3 [00:03<00:01,  1.75s/it]
# Total # of frames saved: 25
# FPS: 5.0
# Samplerate: 2
# Total # of frames: 199
# Duration of Video: 39.8 seconds
# Importing: 100%|██████████| 3/3 [00:04<00:00,  1.60s/it]
# Total # of frames saved: 20
# Number of frames: [33, 25, 20]

# %%
# %load_ext autoreload
# %autoreload 2

import json
from scenic_fc.api import api

PRE_BUILT_FSM = 'jorge-give-and-go_skip_synth'

with open(dir + f'/examples/exports/{PRE_BUILT_FSM}.json', 'r') as json_file:
    data = json.load(json_file)

from synth_utils import Act
combined = Act.from_dict(data, api)

# %%
import copy
final = copy.deepcopy(combined)

# %%
# %load_ext autoreload
# %autoreload 2

from edit_utils import edit_interface, EditLogger
logger = EditLogger()
edit_interface(final, api, logger)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# VBox(children=(Output(), Tab(children=(VBox(children=(HTML(value='<h3>Edit Action</h3>'), Dropdown(description…

# %%
from infer_utils import Inference
final = Inference.fill(final, api, model='gpt-4o')
# Out:
# Editing done.

# %%
final.outline = Inference.outline(final, api)

# %%
# %load_ext autoreload
# %autoreload 2

from synth_utils import Synth

synth = Synth(final, demos, api)
synth.run(logger)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Synthesizing:   0%|          | 0/11 [00:00<?, ?it/s]
# distance from Coach to opponent
# HorizontalRelation {'obj': 'Coach', 'relation': 'left', 'ref': 'teammate'}
# HorizontalRelation {'obj': 'Coach', 'relation': 'right', 'ref': 'teammate'}
# HeightRelation {'obj': 'Coach', 'relation': 'below', 'ref': 'teammate'}
# DistanceTo {'to': 'opponent', 'from': 'Coach', 'operator': 'greater_than'}
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/_methods.py:206: RuntimeWarning:
#
# Degrees of freedom <= 0 for slice
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/_methods.py:163: RuntimeWarning:
#
# invalid value encountered in divide
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/_methods.py:198: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# Synthesizing:   9%|▉         | 1/11 [00:30<05:09, 30.96s/it]
# distance from Coach to opponent
# distance from Coach to opponent
# DistanceTo {'to': 'opponent', 'from': 'Coach', 'operator': 'greater_than'}
# Synthesizing:  27%|██▋       | 3/11 [00:50<02:03, 15.42s/it]
# distance from Coach to opponent
# distance from Coach to goal
# DistanceTo {'to': 'goal', 'from': 'Coach', 'operator': 'less_than'}
# Synthesizing:  36%|███▋      | 4/11 [01:18<02:16, 19.55s/it]
# distance from Coach to goal
# Synthesizing:  64%|██████▎   | 7/11 [01:27<00:34,  8.67s/it]
# MakePass {'player': 'teammate'}
# Synthesizing:  73%|███████▎  | 8/11 [01:33<00:24,  8.10s/it]
# Pressure {'player1': 'opponent', 'player2': 'Coach'}
# Synthesizing:  82%|████████▏ | 9/11 [01:39<00:14,  7.41s/it]
# MovingTowards {'obj': 'opponent', 'ref': 'teammate'}
# Pressure {'player1': 'opponent', 'player2': 'Coach'}
# Synthesizing:  91%|█████████ | 10/11 [01:46<00:07,  7.31s/it]
# distance from Coach to opponent
# DistanceTo {'from': 'Coach', 'to': 'opponent', 'operator': 'greater_than'}
# Synthesizing: 100%|██████████| 11/11 [01:58<00:00, 10.75s/it]
# HasPath {'obj1': 'Coach', 'obj2': 'goal'}

# %%
# %load_ext autoreload
# %autoreload 2

data = synth.to_dict(expanded=True)
with open(f'exports/{DATA_NAME}_after_synth.json', 'w') as f:
        json.dump(data, f, indent=4)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

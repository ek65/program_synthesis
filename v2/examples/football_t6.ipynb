# %%
# %load_ext autoreload

# %%
import os
from unity_utils import UnityTranslator

dir = os.getcwd()
DATA_DIR = dir + '/data/transcript_6'
demos = UnityTranslator.get_from(DATA_DIR, dt=1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import os
# ----> 2 from unity_utils import UnityTranslator
#       4 dir = os.getcwd()
#       5 DATA_DIR = dir + '/data/transcript_6'
#
# ModuleNotFoundError: No module named 'unity_utils'

# %%
from synth_utils import Demo

demos = [
    Demo(id='demo_1', scene=None, language='Hey', video=None),
    Demo(id='demo_1', scene=None, language='Bad', video=None),
]

# %%
from scenic_fc.api import api
from infer_utils import Inference
acts = Inference.act_from(demos, api)

# %%
for a in acts:
    a.show()

# %%
import json

OUT_DIR = 'exports'

os.makedirs(OUT_DIR, exist_ok=True)
for idx, a in enumerate(acts):

    id = f'act_{idx + 1}'
    data = a.to_dict(id=id, expanded=False)

    with open(f'{OUT_DIR}/{id}.json', 'w') as f:
        json.dump(data, f, indent=4)

# %%
# TODO: Automate act editing

# %%
# NOTE: Import final act
act = acts[0]

# %%
# %load_ext autoreload
# %autoreload 2

from synth_utils import Synth

synth = Synth(act, demos, api)
synth.run()

# %%
# %load_ext autoreload
# %autoreload 2

program = synth.to_dict()
print(json.dumps(program, indent=4))

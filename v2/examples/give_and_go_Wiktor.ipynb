# %%
import sys, os

dir = os.path.abspath('..')
sys.path.append(os.path.join(dir))
while not os.path.basename(dir) == 'v2':
    parent = os.path.dirname(dir)
    if parent == dir:
        raise FileNotFoundError("No parent directory named 'v2' found.")
    dir = parent

# %%
DATA_NAME = 'check-Nishant'

# %%
DATA_NAME
# Out:
# 'check-Nishant'

# %%
from unity_utils import UnityTranslator

DATA_DIR = dir + f'/data/{DATA_NAME}'
demos = UnityTranslator.get_from(DATA_DIR, sample_rate=1)

# print(f'Number of frames: {[len(d.video.frame_dir) for d in demos]}')
# Out:
# Importing:   0%|          | 0/5 [00:00<?, ?it/s]
# FPS: 30.0
# Samplerate: 10
# Total # of frames: 2115
# Duration of Video: 70.5 seconds
# Importing:  20%|██        | 1/5 [00:00<00:02,  1.81it/s]
# Total # of frames saved: 8
# FPS: 30.0
# Samplerate: 10
# Total # of frames: 2383
# Duration of Video: 79.43333333333334 seconds
# Importing:  40%|████      | 2/5 [00:01<00:01,  1.89it/s]
# Total # of frames saved: 8
# FPS: 30.0
# Samplerate: 10
# Total # of frames: 1565
# Duration of Video: 52.166666666666664 seconds
# Importing:  60%|██████    | 3/5 [00:01<00:00,  2.21it/s]
# Total # of frames saved: 6
# FPS: 30.0
# Samplerate: 10
# Total # of frames: 1320
# Duration of Video: 44.0 seconds
# Importing: 100%|██████████| 5/5 [00:01<00:00,  2.61it/s]
# Total # of frames saved: 5
# FPS: 30.0
# Samplerate: 10
# Total # of frames: 827
# Duration of Video: 27.566666666666666 seconds
# Total # of frames saved: 3

# %%
from scenic_fc.api import api
from infer_utils import Inference
acts = Inference.act_from(demos, api, model='o4-mini')
# Out:
#   0%|          | 0/5 [00:09<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 from scenic_fc.api import api
#       2 from infer_utils import Inference
# ----> 3 acts = Inference.act_from(demos, api, model='o4-mini')
#
# File ~/Documents/GitHub/narrated_demo/v2/infer_utils.py:116, in Inference.act_from(cls, demos, api, model)
#     113         entries.append(Chat.Entry(role='user', text=pause_frames_info))
#     115 chat = Chat(client, model=model)
# --> 116 response = json.loads(chat(entries, json=True))
#     117 # print(response)
#     118
#     119 # Process the response to ensure keyframe values align with pause times when appropriate
#     120 if hasattr(d, 'pause_times') and d.pause_times:
#
# File ~/Documents/GitHub/narrated_demo/v2/nlp_utils.py:205, in Chat.__call__(self, input, json)
# ...

# %%
from scenic_fc.api import api
from infer_utils_gemini import Inference_Gemini
acts_gemini = Inference_Gemini.act_from(demos, api)
# Out:
# Running Gemini inference: 100%|██████████| 4/4 [01:58<00:00, 29.67s/it]
# Inference done.

# %%
combined = Inference.combine(acts=acts, api=api, model='gpt-4o')
# Out:
# Editing done.

# %%
combined_gemini = Inference_Gemini.combine(acts=acts_gemini, api=api)
# Out:
# Editing done.

# %%
import copy
final = copy.deepcopy(combined)
final_gemini = copy.deepcopy(combined_gemini)

# %%
# %load_ext autoreload
# %autoreload 2

from edit_utils import edit_interface, EditLogger

logger = EditLogger()
edit_interface(final, api, logger)

# %%
# %load_ext autoreload
# %autoreload 2

from edit_utils import edit_interface, EditLogger

logger_gemini = EditLogger()
edit_interface(final_gemini, api, logger_gemini)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ...

# %%
import json

infer_data = combined.to_dict(expanded=False)
with open(f'exports/{DATA_NAME}_infer.json', 'w') as f:
        json.dump(infer_data, f, indent=4)

edit_data = final.to_dict(expanded=False)
with open(f'exports/{DATA_NAME}_edit.json', 'w') as f:
        json.dump(edit_data, f, indent=4)

# %%
import json

infer_data = combined_gemini.to_dict(expanded=False)
with open(f'exports/{DATA_NAME}_Gemini_infer.json', 'w') as f:
        json.dump(infer_data, f, indent=4)

edit_data = final_gemini.to_dict(expanded=False)
with open(f'exports/{DATA_NAME}_Gemini_edit.json', 'w') as f:
        json.dump(edit_data, f, indent=4)

# %%
# %load_ext autoreload
# %autoreload 2

from synth_utils import Synth

synth = Synth(final, demos, api)
synth.run(logger)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Synthesizing:   0%|          | 0/11 [00:00<?, ?it/s]
# HorizontalRelation {'obj': 'Coach', 'relation': 'left', 'ref': 'teammate'}
# HorizontalRelation {'obj': 'Coach', 'relation': 'right', 'ref': 'teammate'}
# /Users/wiktorrajca/Documents/GitHub/narrated_demo/.conda/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/wiktorrajca/Documents/GitHub/narrated_demo/.conda/lib/python3.11/site-packages/numpy/_core/_methods.py:145: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# /Users/wiktorrajca/Documents/GitHub/narrated_demo/.conda/lib/python3.11/site-packages/numpy/_core/_methods.py:223: RuntimeWarning:
#
# Degrees of freedom <= 0 for slice
#
# /Users/wiktorrajca/Documents/GitHub/narrated_demo/.conda/lib/python3.11/site-packages/numpy/_core/_methods.py:181: RuntimeWarning:
#
# invalid value encountered in divide
#
# ...

# %%
# %load_ext autoreload
# %autoreload 2

from synth_utils_gemini import Synth_Gemini

synth_gemini = Synth_Gemini(final_gemini, demos, api)
synth_gemini.run(logger_gemini)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Synthesizing:   0%|          | 0/12 [00:00<?, ?it/s]
# HorizontalRelation {'obj': 'Coach', 'relation': 'left', 'ref': 'teammate'}
# HorizontalRelation {'obj': 'Coach', 'relation': 'right', 'ref': 'teammate'}
# Synthesizing:   8%|▊         | 1/12 [00:23<04:17, 23.40s/it]
# === Gemini Parsed JSON Response Termination ===
# ...

# %%
synth_data = synth.to_dict(expanded=True)
with open(f'exports/{DATA_NAME}_OpenAi_synth.json', 'w') as f:
        json.dump(synth_data, f, indent=4)

# %%
synth_data = synth_gemini.to_dict(expanded=True)
with open(f'exports/{DATA_NAME}_Gemini_synth.json', 'w') as f:
        json.dump(synth_data, f, indent=4)

# %%
final_gemini

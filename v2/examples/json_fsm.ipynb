# %%
import sys, os

dir = os.path.abspath('..')
sys.path.append(os.path.join(dir))
while not os.path.basename(dir) == 'v2':
    parent = os.path.dirname(dir)
    if parent == dir:
        raise FileNotFoundError("No parent directory named 'v2' found.")
    dir = parent

# %%
folder = "pilot9"
scenic_code = "distribute-openai-fsm1"


path_to_scenic = f"/Users/edward_kim/Desktop/TacticalMR/Scenic-main/examples/unity/{folder}/{scenic_code}.scenic"
output_path = f"/Users/edward_kim/Desktop/TacticalMR/UnityProject/Assets/Resources/JSONFSM/{scenic_code}-fsm.json"

# %%
from json_fsm import scenic_to_fsm_json_with_llm

scenic_to_fsm_json_with_llm(path_to_scenic, output_path)
# Out:
# '```json\n{\n  "states": [\n    {\n      "id": 1,\n      "name": "Pass(\\"RightStriker\\")",\n      "description": "Passing to RightStriker."\n    },\n    {\n      "id": 2,\n      "name": "MoveTo(λ_target1(), False)",\n      "description": "Move to support and form a triangle with the strikers and goal."\n    },\n    {\n      "id": 3,\n      "name": "Pass(\\"LeftStriker\\")",\n      "description": "Passing to LeftStriker."\n    },\n    {\n      "id": 4,\n      "name": "MoveTo(λ_target1(), False)",\n      "description": "Move to support and form a triangle with the strikers and goal."\n    },\n    {\n      "id": 5,\n      "name": "Pass(\\"RightWinger\\")",\n      "description": "Passing to RightWinger."\n    },\n    {\n      "id": 6,\n      "name": "MoveTo(λ_target1(), False)",\n      "description": "Move to support and form a triangle with the attacking players and goal."\n    },\n    {\n      "id": 7,\n      "name": "Pass(\\"LeftWinger\\")",\n      "description": "Passing to LeftWin
# ...

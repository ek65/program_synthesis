# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os

dir = os.path.abspath('..')
sys.path.append(os.path.join(dir))
while not os.path.basename(dir) == 'v2':
    parent = os.path.dirname(dir)
    if parent == dir:
        raise FileNotFoundError("No parent directory named 'v2' found.")
    dir = parent

# %%
import json
from translator import *

# %%
PRE_BUILT_FSM = 'daniel-give-and-go_synth'

with open(dir + f'/examples/exports/{PRE_BUILT_FSM}.json', 'r') as json_file:
    data = json.load(json_file)

print(dir)
tactical_mr_dir = '/Users/tcdanielh/TacticalMR'
translate(dir + f'/examples/exports/{PRE_BUILT_FSM}.json', dir, tactical_mr_dir)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 PRE_BUILT_FSM = 'daniel-give-and-go_synth.json'
# ----> 3 with open(dir + f'/examples/exports/{PRE_BUILT_FSM}.json', 'r') as json_file:
#       4     data = json.load(json_file)
#       6 print(dir)
#
# File ~/opt/anaconda3/envs/py311/lib/python3.11/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/tcdanielh/narrated_demo/v2/examples/exports/daniel-give-and-go_synth.json.json'

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
from unity_utils import UnityTranslator
import json

dir = os.getcwd()
DATA_DIR = dir + '/data/give-and-go1-2'
demos = UnityTranslator.get_from(DATA_DIR)
# Out:
# Importing: 100%|██████████████████████████████████| 3/3 [00:05<00:00,  1.67s/it]

# %%
program.to_dict(expanded = True)
# Out:
# {'outline': 'Execute a give-and-go movement to acquire possession of the ball, pass to a teammate, and position oneself effectively to receive a return pass back from the teammate.',
#  'nodes': [{'id': '0',
#    'action': 'GetBallPossession',
#    'info': 'Get possession of the ball.',
#    't': {'demo_0': 2, 'demo_1': 0, 'demo_2': 5},
#    'termination': {'info': {'info': 'Stop when the Coach has the ball.',
#      'logic': ''},
#     'logic': ''}},
#   {'target': {'obj': None,
#     'through': False,
#     'info': 'Pass the ball to the teammate, located on the left side.'},
#    'id': '1',
#    'action': 'Pass',
#    'info': 'Pass the ball to the teammate, located on the left side.',
#    't': {'demo_0': 12, 'demo_1': 6, 'demo_2': 9},
#    'termination': {'info': {'info': 'Stop once the ball is successfully passed to the teammate.',
#      'logic': ''},
#     'logic': ''}},
#   {'target': {'info': 'Position oneself in front of the goal post for the return pass.',
# ...

# %%
import json
OUT_DIR = 'exports'
with open(OUT_DIR+'/synthesized-give-and-go1-2.json', 'r') as json_file:
    data = json.load(json_file)

from synth_utils import Act
from scenic_fc.api import api
program = Act.from_dict(data, api, demos)

# %%
program.edit(api)
